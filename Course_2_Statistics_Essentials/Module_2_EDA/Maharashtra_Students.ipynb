# %%
import numpy as np
import pandas as pd
import seaborn as sns

# %%
nas_df = pd.read_csv('./data/EDA_nas.csv')
nas_df
# Out:
#             STUID        State  District Gender       Age  Category  \
# 0     26011001001  Maharashtra         1   Girl  13 years       3.0
# 1     26011001002  Maharashtra         1   Girl  15 years       3.0
# 2     26011001003  Maharashtra         1   Girl  14 years       3.0
# 3     26011001004  Maharashtra         1    Boy  13 years       3.0
# 4     26011001005  Maharashtra         1   Girl  14 years       3.0
# ...           ...          ...       ...    ...       ...       ...
# 8796  26141270036  Maharashtra        14    Boy  13 years       4.0
# 8797  26141270037  Maharashtra        14    Boy  13 years       3.0
# 8798  26141270038  Maharashtra        14    Boy  14 years       4.0
# 8799  26141270039  Maharashtra        14    Boy  13 years       4.0
# 8800  26141270040  Maharashtra        14    Boy  13 years       4.0
#
#       Same.language    Siblings Handicap      Father.edu  ...  \
# 0               2.0   1 sibling       No      Illiterate  ...
# ...

# %%
nas_df.columns
# Out:
# Index(['STUID', 'State', 'District', 'Gender', 'Age', 'Category',
#        'Same.language', 'Siblings', 'Handicap', 'Father.edu', 'Mother.edu',
#        'Father.occupation', 'Mother.occupation', 'Below.poverty',
#        'Use.calculator', 'Use.computer', 'Use.Internet', 'Use.dictionary',
#        'Read.other.books', 'X..Books', 'Distance', 'Computer.use',
#        'Library.use', 'Like.school', 'Subjects', 'Give.Lang.HW',
#        'Give.Math.HW', 'Give.Scie.HW', 'Give.SoSc.HW', 'Correct.Lang.HW',
#        'Correct.Math.HW', 'Correct.Scie.HW', 'Correct.SocS.HW',
#        'Help.in.Study', 'Private.tuition', 'English.is.difficult',
#        'Read.English', 'Dictionary.to.learn', 'Answer.English.WB',
#        'Answer.English.aloud', 'Maths.is.difficult', 'Solve.Maths',
#        'Solve.Maths.in.groups', 'Draw.geometry', 'Explain.answers',
#        'SocSci.is.difficult', 'Historical.excursions', 'Participate.in.SocSci',
#        'Small.groups.in.SocSci', 'Express.SocSci.views',
# ...

# %%
watch_tv_groupby = nas_df.groupby(nas_df['Watch.TV'])

# %%
watch_tv_groupby.mean()
# Out:
#                      STUID  District  Category  Same.language    Maths..  \
# Watch.TV
# Every day     2.608321e+10  8.185168  2.794070       1.092262  31.742637
# Never         2.609323e+10  9.195402  2.842949       1.122024  29.817151
# Once a month  2.608184e+10  8.058252  2.631206       1.237458  32.519456
# Once a week   2.608564e+10  8.435429  2.786686       1.114325  31.408179
#
#               Reading..  Science..   Social..
# Watch.TV
# Every day     55.292724  36.357915  40.416605
# Never         55.225989  35.638589  39.013252
# Once a month  53.697582  36.786127  40.697143
# Once a week   56.581690  36.467112  41.503168

# %%
father_edu_groupby = nas_df.groupby(nas_df['Father.edu'])

father_edu_groupby.mean()
# Out:
#                        STUID  District  Category  Same.language    Maths..  \
# Father.edu
# Degree & above  2.609066e+10  8.940828  2.990854       1.047478  34.879193
# Illiterate      2.607994e+10  7.864307  2.676849       1.131700  29.126754
# Primary         2.608562e+10  8.428102  2.803657       1.103245  32.561137
# Secondary       2.608594e+10  8.455473  2.866750       1.089928  32.230393
# Sr secondary    2.608394e+10  8.257576  2.835958       1.083763  32.493415
#
#                 Reading..  Science..   Social..
# Father.edu
# Degree & above  71.984706  43.519872  47.655238
# Illiterate      48.380123  34.469750  37.119595
# Primary         56.072083  36.617387  41.126530
# Secondary       57.200083  36.551883  41.435323
# Sr secondary    62.708130  38.943013  43.287351

# %%
play_games_groupby = nas_df.groupby(nas_df['Play.games'])

play_games_groupby.mean()
# Out:
#                      STUID  District  Category  Same.language    Maths..  \
# Play.games
# Every day     2.608407e+10  8.273832  2.760631       1.100361  31.863091
# Never         2.607698e+10  7.559271  2.747541       1.178344  28.500336
# Once a month  2.607990e+10  7.848571  2.880000       1.070175  29.609535
# Once a week   2.608566e+10  8.432640  2.874928       1.101562  31.778717
#
#               Reading..  Science..   Social..
# Play.games
# Every day     54.780136  36.293386  40.394297
# Never         49.107484  32.076954  35.654052
# Once a month  51.951193  35.193375  38.689212
# Once a week   59.627034  37.566767  42.373910

# %%
solve_maths_groupby = nas_df.groupby(nas_df['Solve.Maths'])

solve_maths_groupby.mean()
# Out:
#                     STUID  District  Category  Same.language    Maths..  \
# Solve.Maths
# Agree        2.608489e+10  8.353300  2.772705       1.100046  32.800920
# Disagree     2.608628e+10  8.498429  2.863009       1.094340  30.841321
# Neither      2.607377e+10  7.240741  2.661275       1.135359  29.384388
#
#              Reading..  Science..   Social..
# Solve.Maths
# Agree        56.269443  36.910193  40.871141
# Disagree     56.452403  36.769738  41.436906
# Neither      49.661027  33.091587  36.893655

# %%
mothers_edu_groupby = nas_df.groupby(nas_df['Mother.edu'])

mothers_edu_groupby.mean()
# Out:
#                        STUID  District  Category  Same.language    Maths..  \
# Mother.edu
# Degree & above  2.608681e+10  8.552795  2.961538       1.018634  36.894875
# Illiterate      2.608239e+10  8.108841  2.700169       1.138238  30.143768
# Primary         2.608419e+10  8.283784  2.772532       1.090406  33.257899
# Secondary       2.608678e+10  8.540332  2.910671       1.081528  32.152780
# Sr secondary    2.608053e+10  7.921478  2.819512       1.061321  32.954900
#
#                 Reading..  Science..   Social..
# Mother.edu
# Degree & above  70.294286  45.216812  47.248734
# Illiterate      49.477253  34.625128  38.608030
# Primary         56.306995  36.590412  41.470792
# Secondary       59.685071  37.539292  41.973953
# Sr secondary    66.873282  38.548853  43.174764

# %%
nas_df[nas_df['Mother.edu'] == 'Illiterate'].groupby(nas_df['Siblings']).count()
# Out:
#               STUID  State  District  Gender  Age  Category  Same.language  \
# Siblings
# 1 sibling       533    533       533     532  510       494            525
# 2 siblings      923    923       923     923  905       863            901
# 3 siblings      532    532       532     532  525       501            521
# 4+ siblings     469    469       469     469  456       435            458
# Single child     88     88        88      88   83        75             69
#
#               Siblings  Handicap  Father.edu  ...  Express.science.views  \
# Siblings                                      ...
# 1 sibling          533       497         501  ...                    501
# 2 siblings         923       876         870  ...                    889
# 3 siblings         532       505         502  ...                    509
# 4+ siblings        469       431         443  ...                    445
# Single child        88        70          80  ...                     81
#
# ...

# %%
pd.pivot_table(data=nas_df, values=['Science..'], aggfunc=np.mean, index=['Father.edu', 'Age'])
# Out:
#                           Science..
# Father.edu     Age
# Degree & above 12 years   46.752857
#                13 years   44.805143
#                14 years   42.676944
#                15 years   29.090000
#                16+ years  32.730000
# Illiterate     12 years   29.870000
#                13 years   33.758968
#                14 years   35.319478
#                15 years   33.413333
#                16+ years  33.116786
# Primary        11- years  48.486667
#                12 years   34.121667
#                13 years   37.617555
#                14 years   36.700267
#                15 years   35.162768
#                16+ years  32.364000
# Secondary      11- years  29.696667
#                12 years   33.593810
#                13 years   38.164402
#                14 years   36.738859
#                15 years   32.872800
#                16+ years  30.960000
# Sr secondary   12 years   40.113750
#                13 years   39.046503
# ...
